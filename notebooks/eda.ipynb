# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
sys.path.append(os.path.abspath('..'))

plt.style.use('ggplot')

df0 = pd.read_parquet('../datasets/train_data/train_data_0.pq')

# %%
# Базовая информация о данных
display(df0.head(5))
display(df0.info())
display(df0.describe().round(2))
# Out:
#        id  rn  pre_since_opened  pre_since_confirmed  pre_pterm  pre_fterm  \
# 0  250000   1                 8                    7          7          2
# 1  250000   2                14                    8         12         10
# 2  250000   3                10                    4          8         11
# 3  250000   4                13                   12          8          6
# 4  250000   5                 6                   12          4         14
#
#    pre_till_pclose  pre_till_fclose  pre_loans_credit_limit  \
# 0                4                9                       5
# 1                6                3                      12
# 2                6               13                       5
# 3               13                5                      12
# 4                1                7                       4
#
#    pre_loans_next_pay_summ  ...  enc_paym_21  enc_paym_22  enc_paym_23  \
# 0                        2  ...            3            3            3
# 1                        6  ...            3            3            3
# 2                        2  ...            3            3            3
# 3                        2  ...            3            3            3
# 4                        2  ...            3            3            3
#
#    enc_paym_24  enc_loans_account_holder_type  enc_loans_credit_status  \
# 0            4                              1                        3
# 1            4                              1                        3
# 2            4                              1                        3
# 3            4                              1                        3
# 4            4                              1                        3
#
#    enc_loans_credit_type  enc_loans_account_cur  pclose_flag  fclose_flag
# 0                      4                      1            0            0
# 1                      4                      1            0            0
# 2                      4                      1            0            0
# 3                      4                      1            0            0
# 4                      1                      1            1            0
#
# [5 rows x 61 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 2107305 entries, 0 to 2107304
# Data columns (total 61 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   id                             int64
#  1   rn                             int64
#  2   pre_since_opened               int64
#  3   pre_since_confirmed            int64
#  4   pre_pterm                      int64
#  5   pre_fterm                      int64
#  6   pre_till_pclose                int64
#  7   pre_till_fclose                int64
#  8   pre_loans_credit_limit         int64
#  9   pre_loans_next_pay_summ        int64
#  10  pre_loans_outstanding          int64
#  11  pre_loans_total_overdue        int64
#  12  pre_loans_max_overdue_sum      int64
#  13  pre_loans_credit_cost_rate     int64
#  14  pre_loans5                     int64
#  15  pre_loans530                   int64
#  16  pre_loans3060                  int64
#  17  pre_loans6090                  int64
#  18  pre_loans90                    int64
#  19  is_zero_loans5                 int64
#  20  is_zero_loans530               int64
#  21  is_zero_loans3060              int64
#  22  is_zero_loans6090              int64
#  23  is_zero_loans90                int64
#  24  pre_util                       int64
#  25  pre_over2limit                 int64
#  26  pre_maxover2limit              int64
#  27  is_zero_util                   int64
#  28  is_zero_over2limit             int64
#  29  is_zero_maxover2limit          int64
#  30  enc_paym_0                     int64
#  31  enc_paym_1                     int64
#  32  enc_paym_2                     int64
#  33  enc_paym_3                     int64
#  34  enc_paym_4                     int64
#  35  enc_paym_5                     int64
#  36  enc_paym_6                     int64
#  37  enc_paym_7                     int64
#  38  enc_paym_8                     int64
#  39  enc_paym_9                     int64
#  40  enc_paym_10                    int64
#  41  enc_paym_11                    int64
#  42  enc_paym_12                    int64
#  43  enc_paym_13                    int64
#  44  enc_paym_14                    int64
#  45  enc_paym_15                    int64
#  46  enc_paym_16                    int64
#  47  enc_paym_17                    int64
#  48  enc_paym_18                    int64
#  49  enc_paym_19                    int64
#  50  enc_paym_20                    int64
#  51  enc_paym_21                    int64
#  52  enc_paym_22                    int64
#  53  enc_paym_23                    int64
#  54  enc_paym_24                    int64
#  55  enc_loans_account_holder_type  int64
#  56  enc_loans_credit_status        int64
#  57  enc_loans_credit_type          int64
#  58  enc_loans_account_cur          int64
#  59  pclose_flag                    int64
#  60  fclose_flag                    int64
# dtypes: int64(61)
# memory usage: 980.7 MB
# None
#                id          rn  pre_since_opened  pre_since_confirmed  \
# count  2107305.00  2107305.00        2107305.00           2107305.00
# mean    376296.80        6.82              9.27                 8.45
# std      72011.99        5.28              5.72                 4.78
# min     250000.00        1.00              0.00                 0.00
# 25%     314099.00        3.00              5.00                 5.00
# 50%     376993.00        5.00              9.00                 9.00
# 75%     438725.00       10.00             14.00                12.00
# max     499999.00       50.00             19.00                17.00
#
#         pre_pterm   pre_fterm  pre_till_pclose  pre_till_fclose  \
# count  2107305.00  2107305.00       2107305.00       2107305.00
# mean         8.31        8.29             7.08             8.38
# std          5.29        4.43             5.18             4.22
# min          0.00        0.00             0.00             0.00
# 25%          4.00        6.00             2.00             5.00
# 50%          8.00        8.00             7.00            10.00
# 75%         13.00       11.00            12.00            11.00
# max         17.00       16.00            16.00            15.00
#
#        pre_loans_credit_limit  pre_loans_next_pay_summ  ...  enc_paym_21  \
# count              2107305.00               2107305.00  ...   2107305.00
# mean                     9.72                     2.40  ...         2.31
# std                      5.80                     1.37  ...         1.25
# min                      0.00                     0.00  ...         0.00
# 25%                      5.00                     2.00  ...         3.00
# 50%                     10.00                     2.00  ...         3.00
# 75%                     15.00                     2.00  ...         3.00
# max                     19.00                     6.00  ...         3.00
#
#        enc_paym_22  enc_paym_23  enc_paym_24  enc_loans_account_holder_type  \
# count   2107305.00   2107305.00   2107305.00                     2107305.00
# mean          2.34         2.38         3.56                           1.03
# std           1.23         1.20         1.06                           0.28
# min           0.00         0.00         1.00                           0.00
# 25%           3.00         3.00         4.00                           1.00
# 50%           3.00         3.00         4.00                           1.00
# 75%           3.00         3.00         4.00                           1.00
# max           3.00         3.00         4.00                           6.00
#
#        enc_loans_credit_status  enc_loans_credit_type  enc_loans_account_cur  \
# count               2107305.00             2107305.00             2107305.00
# mean                      2.69                   3.33                   1.00
# std                       0.49                   1.08                   0.05
# min                       0.00                   0.00                   0.00
# 25%                       2.00                   3.00                   1.00
# 50%                       3.00                   4.00                   1.00
# 75%                       3.00                   4.00                   1.00
# max                       6.00                   5.00                   3.00
#
#        pclose_flag  fclose_flag
# count   2107305.00   2107305.00
# mean          0.16         0.24
# std           0.37         0.42
# min           0.00         0.00
# 25%           0.00         0.00
# 50%           0.00         0.00
# 75%           0.00         0.00
# max           1.00         1.00
#
# [8 rows x 61 columns]

# %%
from src.EDA.checkers import min_max_checker

min_max_checker()
# Out:
# Минимум в датасете train_data_0 (без учета id): 0, максимум (без учета id): 51
# Минимум в датасете train_data_1 (без учета id): 0, максимум (без учета id): 50
# Минимум в датасете train_data_2 (без учета id): 0, максимум (без учета id): 51
# Минимум в датасете train_data_3 (без учета id): 0, максимум (без учета id): 50
# Минимум в датасете train_data_4 (без учета id): 0, максимум (без учета id): 45
# Минимум в датасете train_data_5 (без учета id): 0, максимум (без учета id): 47
# Минимум в датасете train_data_6 (без учета id): 0, максимум (без учета id): 54
# Минимум в датасете train_data_7 (без учета id): 0, максимум (без учета id): 55
# Минимум в датасете train_data_8 (без учета id): 0, максимум (без учета id): 48
# Минимум в датасете train_data_9 (без учета id): 0, максимум (без учета id): 49
# Минимум в датасете train_data_10 (без учета id): 0, максимум (без учета id): 45
# Минимум в датасете train_data_11 (без учета id): 0, максимум (без учета id): 58
# Минимум в датасетax (без учета id): 0, максимум (без учета id): 58

# %% [markdown]
# Как мы видим, значения в датасете имеют тип данных int64, а минимум и максимум лежат в диапазоне от 0 до 58 (за исключением id), поэтому все значения можно перевести в int8 для уменьшения памяти

# %%
from src.EDA.checkers import nans_checker

nans_checker()
# Out:
# В данных train_data_0.pq отсутствуют пропущенные значения.
# В данных train_data_1.pq отсутствуют пропущенные значения.
# В данных train_data_2.pq отсутствуют пропущенные значения.
# В данных train_data_3.pq отсутствуют пропущенные значения.
# В данных train_data_4.pq отсутствуют пропущенные значения.
# В данных train_data_5.pq отсутствуют пропущенные значения.
# В данных train_data_6.pq отсутствуют пропущенные значения.
# В данных train_data_7.pq отсутствуют пропущенные значения.
# В данных train_data_8.pq отсутствуют пропущенные значения.
# В данных train_data_9.pq отсутствуют пропущенные значения.
# В данных train_data_10.pq отсутствуют пропущенные значения.
# В данных train_data_11.pq отсутствуют пропущенные значения.

# %% [markdown]
# Так как пропущенные значения отстуствуют везде, обработка на них излишняя

# %%
from src.EDA.data_preprocessing import data_preprocessing
# Обработка данных
from src.schema import category_cols, binary_cols
df0 = data_preprocessing(df0, category_cols=category_cols, binary_cols=binary_cols)

# %%
display(df0.head(5))
display(df0.info())
display(df0.describe().round(2))
# Out:
#        id  rn  pre_since_opened  pre_since_confirmed  pre_pterm  pre_fterm  \
# 0  250000   1                 8                    7          7          2
# 1  250000   2                14                    8         12         10
# 2  250000   3                10                    4          8         11
# 3  250000   4                13                   12          8          6
# 4  250000   5                 6                   12          4         14
#
#    pre_till_pclose  pre_till_fclose  pre_loans_credit_limit  \
# 0                4                9                       5
# 1                6                3                      12
# 2                6               13                       5
# 3               13                5                      12
# 4                1                7                       4
#
#    pre_loans_next_pay_summ  ...  enc_paym_21  enc_paym_22  enc_paym_23  \
# 0                        2  ...            3            3            3
# 1                        6  ...            3            3            3
# 2                        2  ...            3            3            3
# 3                        2  ...            3            3            3
# 4                        2  ...            3            3            3
#
#    enc_paym_24  enc_loans_account_holder_type  enc_loans_credit_status  \
# 0            4                              1                        3
# 1            4                              1                        3
# 2            4                              1                        3
# 3            4                              1                        3
# 4            4                              1                        3
#
#    enc_loans_credit_type  enc_loans_account_cur  pclose_flag  fclose_flag
# 0                      4                      1        False        False
# 1                      4                      1        False        False
# 2                      4                      1        False        False
# 3                      4                      1        False        False
# 4                      1                      1         True        False
#
# [5 rows x 61 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 2107305 entries, 0 to 2107304
# Data columns (total 61 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   id                             int64
#  1   rn                             int8
#  2   pre_since_opened               int8
#  3   pre_since_confirmed            int8
#  4   pre_pterm                      int8
#  5   pre_fterm                      int8
#  6   pre_till_pclose                int8
#  7   pre_till_fclose                int8
#  8   pre_loans_credit_limit         int8
#  9   pre_loans_next_pay_summ        int8
#  10  pre_loans_outstanding          int8
#  11  pre_loans_total_overdue        int8
#  12  pre_loans_max_overdue_sum      int8
#  13  pre_loans_credit_cost_rate     int8
#  14  pre_loans5                     int8
#  15  pre_loans530                   int8
#  16  pre_loans3060                  int8
#  17  pre_loans6090                  int8
#  18  pre_loans90                    int8
#  19  is_zero_loans5                 int8
#  20  is_zero_loans530               int8
#  21  is_zero_loans3060              int8
#  22  is_zero_loans6090              int8
#  23  is_zero_loans90                int8
#  24  pre_util                       int8
#  25  pre_over2limit                 int8
#  26  pre_maxover2limit              int8
#  27  is_zero_util                   bool
#  28  is_zero_over2limit             int8
#  29  is_zero_maxover2limit          int8
#  30  enc_paym_0                     category
#  31  enc_paym_1                     category
#  32  enc_paym_2                     category
#  33  enc_paym_3                     category
#  34  enc_paym_4                     category
#  35  enc_paym_5                     category
#  36  enc_paym_6                     category
#  37  enc_paym_7                     category
#  38  enc_paym_8                     category
#  39  enc_paym_9                     category
#  40  enc_paym_10                    category
#  41  enc_paym_11                    category
#  42  enc_paym_12                    category
#  43  enc_paym_13                    category
#  44  enc_paym_14                    category
#  45  enc_paym_15                    category
#  46  enc_paym_16                    category
#  47  enc_paym_17                    category
#  48  enc_paym_18                    category
#  49  enc_paym_19                    category
#  50  enc_paym_20                    category
#  51  enc_paym_21                    category
#  52  enc_paym_22                    category
#  53  enc_paym_23                    category
#  54  enc_paym_24                    category
#  55  enc_loans_account_holder_type  category
#  56  enc_loans_credit_status        category
#  57  enc_loans_credit_type          category
#  58  enc_loans_account_cur          int8
#  59  pclose_flag                    bool
#  60  fclose_flag                    bool
# dtypes: bool(3), category(28), int64(1), int8(29)
# memory usage: 136.7 MB
# None
#                id          rn  pre_since_opened  pre_since_confirmed  \
# count  2107305.00  2107305.00        2107305.00           2107305.00
# mean    376296.80        6.82              9.27                 8.45
# std      72011.99        5.28              5.72                 4.78
# min     250000.00        1.00              0.00                 0.00
# 25%     314099.00        3.00              5.00                 5.00
# 50%     376993.00        5.00              9.00                 9.00
# 75%     438725.00       10.00             14.00                12.00
# max     499999.00       50.00             19.00                17.00
#
#         pre_pterm   pre_fterm  pre_till_pclose  pre_till_fclose  \
# count  2107305.00  2107305.00       2107305.00       2107305.00
# mean         8.31        8.29             7.08             8.38
# std          5.29        4.43             5.18             4.22
# min          0.00        0.00             0.00             0.00
# 25%          4.00        6.00             2.00             5.00
# 50%          8.00        8.00             7.00            10.00
# 75%         13.00       11.00            12.00            11.00
# max         17.00       16.00            16.00            15.00
#
#        pre_loans_credit_limit  pre_loans_next_pay_summ  ...  is_zero_loans530  \
# count              2107305.00               2107305.00  ...        2107305.00
# mean                     9.72                     2.40  ...              0.84
# std                      5.80                     1.37  ...              0.36
# min                      0.00                     0.00  ...              0.00
# 25%                      5.00                     2.00  ...              1.00
# 50%                     10.00                     2.00  ...              1.00
# 75%                     15.00                     2.00  ...              1.00
# max                     19.00                     6.00  ...              1.00
#
#        is_zero_loans3060  is_zero_loans6090  is_zero_loans90    pre_util  \
# count         2107305.00         2107305.00       2107305.00  2107305.00
# mean                0.96               0.98             0.98       13.86
# std                 0.20               0.14             0.14        4.40
# min                 0.00               0.00             0.00        0.00
# 25%                 1.00               1.00             1.00       15.00
# 50%                 1.00               1.00             1.00       16.00
# 75%                 1.00               1.00             1.00       16.00
# max                 1.00               1.00             1.00       19.00
#
#        pre_over2limit  pre_maxover2limit  is_zero_over2limit  \
# count      2107305.00         2107305.00          2107305.00
# mean             2.18              15.67                0.94
# std              0.82               4.03                0.24
# min              0.00               0.00                0.00
# 25%              2.00              17.00                1.00
# 50%              2.00              17.00                1.00
# 75%              2.00              17.00                1.00
# max             19.00              19.00                1.00
#
#        is_zero_maxover2limit  enc_loans_account_cur
# count             2107305.00             2107305.00
# mean                    0.85                   1.00
# std                     0.36                   0.05
# min                     0.00                   0.00
# 25%                     1.00                   1.00
# 50%                     1.00                   1.00
# 75%                     1.00                   1.00
# max                     1.00                   3.00
#
# [8 rows x 30 columns]

# %% [markdown]
# Память занимаемая датасетом уменьшилась с 980 мб до 136, что позволит нашей программе работать быстрее

# %%
dft = pd.read_csv('../datasets/train_target.csv')
defalt_customers_count = dft['flag'].sum() / len(dft)  # Доля дефолтных клиентов в обучающей выборке
print(f'Доля дефолтных клиентов в обучающей выборке: {defalt_customers_count:.2%}')
# Out:
# Доля дефолтных клиентов в обучающей выборке: 3.55%

# %%
data = df0.groupby('id')['rn'].max()

plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, color='C1', alpha=0.7, edgecolor='black', label='Количество кредитов на клиента')
plt.xlabel('Количество кредитов на клиента')
plt.ylabel('Частота')
plt.title('Распределение количества кредитов на клиента')
plt.legend()
plt.show()
